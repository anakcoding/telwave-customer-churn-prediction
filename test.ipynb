# %%
import pandas as pd

# %%
df = pd.read_csv('example-data-test.csv')

# %%
df
# Out:
#     CustomerID  Gender  SeniorCitizen  Age Married              City  \
# 0   7591-VHVEG    Male              0   42     Yes     San Francisco
# 1   5576-GNVDE  Female              0   35      No       Los Angeles
# 2   3669-QPYBK    Male              0   28      No         San Diego
# 3   7796-CFOCW  Female              0   51     Yes        Sacramento
# 4   9238-HQITU    Male              0   22      No          San Jose
# 5   9306-CDSKC  Female              0   39     Yes        Long Beach
# 6   1453-KIOVK    Male              0   47      No           Oakland
# 7   6714-OKOMC  Female              0   31      No            Fresno
# 8   7893-POOKP    Male              0   25     Yes           Anaheim
# 9   6389-TABGU  Female              0   58      No         Santa Ana
# 10  9764-GRSKD    Male              0   33     Yes         Riverside
# 11  7470-LKBCI  Female              0   45      No       Bakersfield
# 12  8092-TTVAX    Male              0   36     Yes          Stockton
# ...

# %%
print(df.dtypes)
# Out:
# CustomerID                        object
# Gender                            object
# SeniorCitizen                      int64
# Age                                int64
# Married                           object
# City                              object
# Country                           object
# ZipCode                            int64
# Population                       float64
# Latitude                         float64
# Longitude                        float64
# Partner                           object
# Dependents                        object
# PhoneService                      object
# MultipleLines                     object
# InternetService                   object
# StreamingTV                       object
# StreamingMovies                   object
# StreamingMusic                    object
# UnlimitedData                     object
# Contract                          object
# PaperlessBilling                  object
# PaymentMethod                     object
# ...

# %%
df.dropna(inplace=True,axis=1)

# %%
df.isna().count()
# Out:
# CustomerID                       4
# Gender                           4
# SeniorCitizen                    4
# Age                              4
# Married                          4
# City                             4
# Country                          4
# ZipCode                          4
# Population                       4
# Latitude                         4
# Longitude                        4
# Partner                          4
# Dependents                       4
# PhoneService                     4
# MultipleLines                    4
# InternetService                  4
# StreamingTV                      4
# StreamingMovies                  4
# StreamingMusic                   4
# UnlimitedData                    4
# Contract                         4
# PaperlessBilling                 4
# PaymentMethod                    4
# OnlineSecurity                   4
# OnlineBackup                     4
# DeviceProtection                 4
# TechSupport                      4
# ...

# %%
df_clean= df.drop(columns=['CustomerID','Latitude', 'Longitude', 'ZipCode','City','ChurnCategory','ChurnReason', 'ChurnScore', 'Country', 'ReferredFriend'],axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#     CustomerID  Gender  SeniorCitizen  Age Married              City  \
# 20  8780-QRDMV    Male              1   65      No  Huntington Beach
# 26  6468-CHFZW    Male              0   59     Yes          Pasadena
# 27  8666-UTDHZ    Male              0   28     Yes         Escondido
# 29  8774-HHUOZ  Female              0   21      No           Concord
#
#           Country  ZipCode  Population  Latitude  ...  TotalExtraDataCharges  \
# 20  United States    92646     19800.0   33.6784  ...                   20.0
# 26  United States    91101     16812.0   34.1466  ...                    0.0
# 27  United States    92025     49281.0   33.0815  ...                    0.0
# 29  United States    94520     12900.0   37.9780  ...                    0.0
#
#    TotalLongDistanceCharges TotalRefunds TotalRevenue AvgMonthlyGBDownload  \
# 20                      0.0          0.0        59.65                  8.0
# 26                   1380.6          0.0      5752.00                 15.0
# ...
